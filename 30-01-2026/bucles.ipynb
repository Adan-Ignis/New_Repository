# %% [markdown]
# Bucles while

# %%
contador = 0
while contador < 10:
    print(contador)
    contador += 1

print("Fuera del bucle")

# %%
final = 10
control = 0

while True:
	print(f"Hola {control}")
	if control == final:
		break
	else:

# %%
for i in range(1, 51):
	print(i)

# %%
i = 1
while i < 51:
	print(i)
	i += 1

# %%
cadena = "Esta es una prueba de while"
control = 0
while control <= len(cadena):
	print(cadena[control])
	control += 1

print("Se acabo")

# %%
kg = float(input("Dime un peso en kg"))
FACTOR = 2.204623
while KG >= 0:
	kg = float(input("Dime un peso en kg"))

print(f'{kg} kilos son {kg * FACTOR} libras')

# %%
clave = "manolito"
intentos = 0
while intentos < 3:
	user_pass = input("Introduzca la clave: ")
	if clave != user_pass:
		print("Clave incorrecta")
		intentos += 1
	else:
		print("Bienvenido. Has entrado")
		break

if intentos == 3:
	print("Expulsados del sistema")

# %%
puntajes = []
mas_90 = 0
promedio = 0

while True:
	numero = int(input("Dime un numero"))
	if numero < 0:
		break
	puntuajes.append(numero)
	if numero >= 90:
		mas_90 += 1

promedio = sum(puntajes) / len(puntajes)

print(f'Promedio: {promedio}')
